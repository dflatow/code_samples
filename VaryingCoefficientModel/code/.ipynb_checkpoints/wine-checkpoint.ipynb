# %%
import pandas as pd
import sklearn
from sklearn import cross_validation, decomposition
from sklearn.preprocessing import PolynomialFeatures
#(degree=2, interaction_only=False, include_bias=True)
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../data/wine.train.csv')
df['color'] = (df.color == 'red').astype(float)
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df['color'] = df['color'] + np.random.normal(0, 0.05, size=len(df['color']))

# %%
df.plot(x="color", y="residual.sugar", kind="scatter")

# %%
df['log.residual.sugar'] = np.log(df['residual.sugar'])
df = df.drop(['residual.sugar'], axis=1)

# %%
print df[df.density >= 1.004].T
df = df[df.density < 1.004]
# Out:
# Empty DataFrame
# Columns: []
# Index: [fixed.acidity, volatile.acidity, citric.acid, chlorides, free.sulfur.dioxide, total.sulfur.dioxide, density, pH, sulphates, alcohol, quality, log.residual.sugar]

# %%
X = df.iloc[:,:-2]
y = df.iloc[:, -2]

X = PolynomialFeatures(degree=2, interaction_only=False, include_bias=True).fit_transform(X)
X = decomposition.PCA(n_components=60).fit_transform(X)

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.7, random_state=0)

# %%
m = pd.ols(y=y_train, x = pd.DataFrame(X_train))
Z = m.predict(x=pd.DataFrame(X_test)).round()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

params = [1, 5, 10, 20, 50, 100, 150, 200]
for n in params:
    clf = neighbors.KNeighborsRegressor(n, weights='distance')
    scores = cross_validation.cross_val_score(clf, X_train, y_train, cv=3, scoring='mean_squared_error')
    print np.sqrt(scores)
    #print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-49a255d689ff> in <module>()
#       7 for n in params:
#       8     clf = neighbors.KNeighborsRegressor(n, weights='distance')
# ----> 9     scores = cross_validation.cross_val_score(clf, X_train, y_train, cv=3, scoring='mean_squared_error')
#      10     print np.sqrt(scores)
#      11     #print("MSE: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
#
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, score_func, pre_dispatch)
#    1149                                               train, test, verbose, None,
#    1150                                               fit_params)
# -> 1151                       for train, test in cv)
#    1152     return np.array(scores)[:, 0]
#    1153
#
# ...
